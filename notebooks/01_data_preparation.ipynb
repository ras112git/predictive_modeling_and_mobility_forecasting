# %%
print("Kernel working properly")
# Out:
# Kernel working properly

# %% [markdown]
# # Data preparation and exploration notebook
#
# This notebook will focus into running the data download files, as well as preparing the data for the training later on.

# %% [markdown]
# ## Cloning the repository - Google Colab
#
# This step is needed for importing the src scripts. This is needed when execution through google colab

# %%
# !pip install -U ipython

# %%
# %load_ext autoreload
# %autoreload 2

#Clone the repository
import os
if not os.path.exists("predictive_modeling_and_mobility_forecasting"):
    # !git clone https://github.com/ras112git/predictive_modeling_and_mobility_forecasting.git
else:
    print("Repo already cloned.")


# %cd predictive_modeling_and_mobility_forecasting

# Install dependencies
# !pip install -r requirements.txt

import sys
sys.path.append(os.getcwd())

# %% [markdown]
# ## Setting up environment localy (venv)

# %% [markdown]
# Local set up
# ```bash
# python -m venv .venv
# .venv\Scripts\activate          # Windows
# pip install -r requirements.txt
# pip install jupyter ipykernel
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
from pathlib import Path

# Make src/ importable: add the project root (parent of notebooks/) to sys.path
project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Run from the project root so relative paths like "data/raw/..." resolve
os.chdir(project_root)
print(f"Working dir: {os.getcwd()}")
# Out:
# Working dir: c:\Users\rcsrc\Documents\GitHub\predictive_modeling_and_mobility_forecasting

# %% [markdown]
# ## Download the raw data

# %%
from src.download_data import download_raw_data

train_path, test_path = download_raw_data()
# Out:
# Downloading dataset_train.csv from Google Drive...
# Downloading...
# From (original): https://drive.google.com/uc?id=13p_DwfnywGNLFgovm_RWRs-ZnKsEjPdc
# From (redirected): https://drive.google.com/uc?id=13p_DwfnywGNLFgovm_RWRs-ZnKsEjPdc&confirm=t&uuid=df8a8445-cffa-4605-8442-930c63584671
# To: c:\Users\rcsrc\Documents\GitHub\predictive_modeling_and_mobility_forecasting\data\raw\dataset_train.csv
# 100%|██████████| 122M/122M [00:18<00:00, 6.59MB/s]
# Saved to data/raw\dataset_train.csv
# Downloading dataset_test.csv from Google Drive...
# Downloading...
# From: https://drive.google.com/uc?id=1xTFvlyL-te42wvR3s-NN02qNGtz1VqOQ
# To: c:\Users\rcsrc\Documents\GitHub\predictive_modeling_and_mobility_forecasting\data\raw\dataset_test.csv
# 100%|██████████| 29.3M/29.3M [00:05<00:00, 5.75MB/s]
# Saved to data/raw\dataset_test.csv

# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd

df_train = pd.read_csv(train_path)
df_test = pd.read_csv(test_path)

print(f"Train shape: {df_train.shape}")
print(f"Test shape:  {df_test.shape}")

df_train.head()
